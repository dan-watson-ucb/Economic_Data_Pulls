# %%
import pandas as pd
from fredapi import Fred
from api_key import fred_key

# %%
fred = Fred(api_key= fred_key)

# %%
data = fred.get_series('SP500')

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
fred.search('population forsyth county NC').T
# Out:
# series id                                                         NCFORS5URN  \
# id                                                                NCFORS5URN
# realtime_start                                           2021-03-10 00:00:00
# realtime_end                                             2021-03-10 00:00:00
# title                                Unemployment Rate in Forsyth County, NC
# observation_start                                        1990-01-01 00:00:00
# observation_end                                          2020-12-01 00:00:00
# frequency                                                            Monthly
# frequency_short                                                            M
# units                                                                Percent
# units_short                                                                %
# seasonal_adjustment                                  Not Seasonally Adjusted
# ...

# %%
data = fred.get_series('ATNHPIUS37067A')

# %%
forsyth_pop = fred.get_series('NCFORS5POP')

# %%
forsyth_pop.plot()
# Out:
# <AxesSubplot:>
